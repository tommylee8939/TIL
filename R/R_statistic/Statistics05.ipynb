# %% [markdown]
# ### Kernel Density Estimation(KDE)
# - 솔직히 이해가 잘 안가는 부분이다
# - optimal한 h값 찾는 수학적 증명이 어렵다

# %%
## 두 분포의 합

# 한국 사람의 키의 분포가 정규분포를 따른다고 생각을 해보자

sample<-data.frame(키=rnorm(100,165,10),성별=rbinom(100,1,1/3))
# 성별을 먼저 factor처리해보자
sample$성별<-factor(sample$성별)
levels(sample$성별)<-c("남","여")
head(sample)
# Out:
#   키       성별
# 1 163.9251 남
# 2 170.1494 여
# 3 164.2732 남
# 4 175.0741 남
# 5 143.3210 여
# 6 167.5682 남

# %%
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
ggplot(data = sample,aes(x=키))+
    geom_density()
# Out:
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '키' in 'mbcsToSbcs': dot substituted for <ed>”Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '키' in 'mbcsToSbcs': dot substituted for <82>”Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '키' in 'mbcsToSbcs': dot substituted for <a4>”Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '키' in 'mbcsToSbcs': dot substituted for <ed>”Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# “conversion failure on '키' in 'mbcsToSbcs': dot substituted for <82>”Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# ...
