# %% [markdown]
# ### Bootstrap Method

# %%
sample<-rnorm(100,10,10) # rate = 10을 모른다고 가정해보자

result<-c()
for (i in 1:5000){
    result<-append(result,mean(sample(sample,size =1000 ,replace = T)))   
}

hist(sample)
hist(result)
# Out:
# Plot with title “Histogram of sample”
# Plot with title “Histogram of result”

# %%
a<-c()
for (i in 1:10000){
    a<-append(a,mean(rnorm(100)))
}
mean(a)
# Out:
# [1] -0.0007550621
