# %%
data<-rexp(1000)

data2<-rnorm(1000,10,20)

par(mfrow=c(1,2))
plot(ecdf(data))
plot(ecdf(data2))
# Out:
# Plot with title “ecdf(data2)”

# %%
plot(ecdf(rnorm(1000,0,1)))
# Out:
# Plot with title “ecdf(rnorm(1000, 0, 1))”
