# %%
import numpy as np
import pandas as pd


from datetime import date,datetime,timedelta
from dateutil.parser import parse

import json
import re
from glob import glob

# 시각화
# %matplotlib inline
import seaborn as sns
import folium as g

import matplotlib.pyplot as plt
from matplotlib import rc
# 한글 폰트 문제 해결
rc('font', family='AppleGothic')
# 차트 축 <- 음수 부호 지원
plt.rcParams['axes.unicode_minus'] = False


# 크롤링
from bs4 import BeautifulSoup
from urllib.request import urlopen, urlretrieve
from urllib.error   import HTTPError
from urllib.error   import URLError

from selenium import webdriver

# %% [markdown]
# ### Selenium 함수
# - find_element_by_XXXX()
# - find_elements_by_XXXX()
#
#     - by _css_selector, _tag_name, _name, _id

# %%
path = './driver/chromedriver'
driver = webdriver.Chrome(path)
driver.get('https://python.org')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
driver.find_element_by_css_selector('#top > nav > ul > li.psf-meta') # li.psf-meta li인데 class가 psf-meta인 것
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e8e8eece0361a67d7402b894c0b93575", element="c3c5e527-8757-482a-95b6-349851549812")>]

# %%
driver.find_elements_by_css_selector('#top > nav > ul > li')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e8e8eece0361a67d7402b894c0b93575", element="0a2881e8-48bb-40ef-91c7-30ff9be347cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e8e8eece0361a67d7402b894c0b93575", element="c3c5e527-8757-482a-95b6-349851549812")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e8e8eece0361a67d7402b894c0b93575", element="ec173a14-3e74-4f9b-9aeb-25682f48b5e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e8e8eece0361a67d7402b894c0b93575", element="49c6ad09-ff6a-4b0b-b634-a48240391f05")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e8e8eece0361a67d7402b894c0b93575", element="3d19b49a-66d1-43a6-ac4f-79ad59a81327")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="e8e8eece0361a67d7402b894c0b93575", element="fffd45a4-b7e2-41d8-b852-6ae2de00bac2")>]

# %%
for i in driver.find_elements_by_css_selector('#top > nav > ul > li'):
    print(i.text)
# Out:
# Python
# PSF
# Docs
# PyPI
# Jobs
# Community

# %%
menu = driver.find_elements_by_css_selector('#top > nav > ul > li')
menu[3].click()

# %%
path = './driver/chromedriver'
driver = webdriver.Chrome(path)
driver.get('https://datalab.naver.com/shoppingInsight/sCategory.naver')

# %%
driver.find_elements_by_css_selector('.rank_top1000_list li')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="72458a8b-9871-42a6-bb62-7accf63cab5f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="a1570889-7522-487e-bd57-5640ca4a6a49")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="88720259-452a-446e-992f-9cb034af6625")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="2df2b457-de63-45d3-9097-53dd09984310")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="693ec14a-d438-48d3-9287-c714ab239679")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="4d4afa10-17fd-4ac6-ba49-e36d02ff78ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="583e4cc9-79d5-4700-829f-bae9cc63809e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="03c10e72-e8e1-4d86-9418-ca748ab8f280")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="5895d399-0ba6-422b-9706-a9c1bdf9341a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="44d1e495-29ca-4bf0-ba59-613dba28b0e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="effaa79f-ead7-47b4-94ee-14c7969558ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="00cfa273-d5f8-4765-bde9-4a9247f0b714")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="838e2f0c-030d-43dd-ac81-1a5c2728e1db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="063b95c0-f650-4750-ae01-9c66c061972b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="b7700a51-f6cd-45ce-9fc3-5d4a73c28b8e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="4bd91af8-a513-4acb-b02b-a2928ea416bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="3796cb31-e993-4e8f-b131-1453bf01b0f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="0541afca-cc46-4862-84be-b9efdf6ee099")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="4f14aa5a-ea5a-47c1-90b6-83c2b4cfb51f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2619d9d6324526c289ed4219b7ea4aad", element="0e191e49-7590-485f-b721-46d588fa6262")>]

# %%
next_btn = driver.find_element_by_css_selector('.btn_page_box a.btn_page_next')
for i in range(0,25):
    for j in driver.find_elements_by_css_selector('.rank_top1000_list li'):
        print(j.text)
    next_btn.click()
# Out:
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스
# 481
# 나이키에센셜프렌치테리
# 482
# 지센
# 483
# 나인
# 484
# 트레이닝바지
# 485
# 트위드조끼
# 486
# 언더아머반팔
# 487
# 여성청바지
# 488
# 헤지스여성티셔츠
# 489
# 르샵원피스
# 490
# 모조에스핀자켓
# 491
# 프릴블라우스
# 492
# 씨씨콜렉트블라우스
# 493
# 꼼빠니아원피스
# 494
# 바버
# 495
# 오버핏후드티
# 496
# 시슬리블라우스
# 497
# 메종키츠네니트
# 498
# 남자청자켓
# 499
# 산드로원피스
# 500
# 자바나스

# %%
for i in range(0,25):
